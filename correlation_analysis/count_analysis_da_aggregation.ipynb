# %%
# %load_ext autoreload
# %autoreload 2
from typing import Set, List, Callable
import sys 
sys.path.append('.')
import pickle
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib as mpl
from tqdm import tqdm
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# mpl.rc('font', size=14)

# %% [markdown]
# # Count Analysis:
# ## How many bad models (on target) are there in our experiments based on a specific measure?
#
# **Measure**: Count how often a model achieves less than X percent of the source accuracy on target.
#
# **Best result:** We have lots of bad models in our experiment and our method IWA performs well in this setting.
#
#
# **Procedure:**
# 1. load results table

# %% [markdown]
# ### Load preprocessed results of all experiments
# To perform this analysis, we must at first load all results.
# For an explanation of how to best preprocess, store and load experiment results, have a look at this repo: [https://github.com/maximilianmbeck/viz](https://github.com/maximilianmbeck/viz).

# %%
# load all results
results_file = './data/iclr_all_results_dfs.p'
with open(results_file, 'rb') as f:
    # results are stored as a nested dictionary
    results_dict = pickle.load(f)
results_dict.keys()
# Out:
# dict_keys(['MINI_DOMAIN_NET', 'WISDM', 'HAR', 'HHAR_SA', 'AMAZON_REVIEWS', 'EEG', 'MOONS'])

# %% [markdown]
# ### Combine all accuracy tables into one big table

# %%
index_tuples = []
acc_df_list = []
for dataset, da_methods_dict in results_dict.items():
    for da_method, result_df_dict in tqdm(da_methods_dict.items(), desc=f'CA for {dataset}'):
        acc_df = result_df_dict['acc_df']
        index_tuples.append((dataset, da_method))
        acc_df_list.append(acc_df)
# combine all in one dataframe
acc_index = pd.MultiIndex.from_tuples(index_tuples, names=['dataset', 'da_method'])
acc_df = pd.concat(acc_df_list, axis=0, keys=acc_index)
acc_df = acc_df.reindex(sorted(acc_df.columns), axis=1)
# Out:
# CA for MINI_DOMAIN_NET: 100%|██████████| 11/11 [00:00<00:00, 182361.04it/s]
# CA for WISDM: 100%|██████████| 11/11 [00:00<00:00, 200597.15it/s]
# CA for HAR: 100%|██████████| 11/11 [00:00<00:00, 152268.46it/s]
# CA for HHAR_SA: 100%|██████████| 11/11 [00:00<00:00, 66194.18it/s]
# CA for AMAZON_REVIEWS: 100%|██████████| 11/11 [00:00<00:00, 111712.70it/s]
# CA for EEG: 100%|██████████| 11/11 [00:00<00:00, 138550.58it/s]
# CA for MOONS: 100%|██████████| 11/11 [00:00<00:00, 172154.27it/s]

# %%
acc_df
# Out:
#                                                                    0  \
# dataset         da_method domains              seed domain
# MINI_DOMAIN_NET HoMM      real_src-clipart_tgt 1    source  0.971487
#                                                     target  0.557377
#                                                2    source  0.979633
#                                                     target  0.590164
#                                                3    source  0.963340
# ...                                                              ...
# MOONS           DSAN      0_src-1_tgt          1    target  1.000000
#                                                2    source  1.000000
#                                                     target  0.988571
#                                                3    source  1.000000
#                                                     target  0.982857
#
#                                                               0.0001  \
# dataset         da_method domains              seed domain
# MINI_DOMAIN_NET HoMM      real_src-clipart_tgt 1    source  0.973523
#                                                     target  0.573770
#                                                2    source  0.963340
#                                                     target  0.540984
#                                                3    source  0.957230
# ...                                                              ...
# MOONS           DSAN      0_src-1_tgt          1    target  1.000000
#                                                2    source  1.000000
#                                                     target  1.000000
#                                                3    source  1.000000
#                                                     target  0.994286
#
#                                                                0.001  \
# dataset         da_method domains              seed domain
# MINI_DOMAIN_NET HoMM      real_src-clipart_tgt 1    source  0.947047
#                                                     target  0.565574
#                                                2    source  0.955193
#                                                     target  0.590164
#                                                3    source  0.967413
# ...                                                              ...
# MOONS           DSAN      0_src-1_tgt          1    target  0.977143
#                                                2    source  1.000000
#                                                     target  1.000000
#                                                3    source  1.000000
#                                                     target  1.000000
#
#                                                                 0.01  \
# dataset         da_method domains              seed domain
# MINI_DOMAIN_NET HoMM      real_src-clipart_tgt 1    source  0.926680
#                                                     target  0.663934
#                                                2    source  0.955193
#                                                     target  0.540984
#                                                3    source  0.973523
# ...                                                              ...
# MOONS           DSAN      0_src-1_tgt          1    target  0.994286
#                                                2    source  1.000000
#                                                     target  1.000000
#                                                3    source  1.000000
#                                                     target  0.994286
#
#                                                                 0.05  \
# dataset         da_method domains              seed domain
# MINI_DOMAIN_NET HoMM      real_src-clipart_tgt 1    source       NaN
#                                                     target       NaN
#                                                2    source       NaN
#                                                     target       NaN
#                                                3    source       NaN
# ...                                                              ...
# MOONS           DSAN      0_src-1_tgt          1    target  0.982857
#                                                2    source  1.000000
#                                                     target  1.000000
#                                                3    source  1.000000
#                                                     target  1.000000
#
#                                                                  0.1  0.25  \
# dataset         da_method domains              seed domain
# MINI_DOMAIN_NET HoMM      real_src-clipart_tgt 1    source  0.947047   NaN
#                                                     target  0.606557   NaN
#                                                2    source  0.967413   NaN
#                                                     target  0.565574   NaN
#                                                3    source  0.963340   NaN
# ...                                                              ...   ...
# MOONS           DSAN      0_src-1_tgt          1    target  1.000000   1.0
#                                                2    source  1.000000   1.0
#                                                     target  1.000000   1.0
#                                                3    source  1.000000   1.0
#                                                     target  1.000000   1.0
#
#                                                             0.5  0.75  \
# dataset         da_method domains              seed domain
# MINI_DOMAIN_NET HoMM      real_src-clipart_tgt 1    source  NaN   NaN
#                                                     target  NaN   NaN
#                                                2    source  NaN   NaN
#                                                     target  NaN   NaN
#                                                3    source  NaN   NaN
# ...                                                         ...   ...
# MOONS           DSAN      0_src-1_tgt          1    target  1.0   1.0
#                                                2    source  1.0   1.0
#                                                     target  1.0   1.0
#                                                3    source  1.0   1.0
#                                                     target  1.0   1.0
#
#                                                                    1  ...  \
# dataset         da_method domains              seed domain            ...
# MINI_DOMAIN_NET HoMM      real_src-clipart_tgt 1    source  0.942974  ...
#                                                     target  0.565574  ...
#                                                2    source  0.963340  ...
#                                                     target  0.565574  ...
#                                                3    source  0.973523  ...
# ...                                                              ...  ...
# MOONS           DSAN      0_src-1_tgt          1    target  1.000000  ...
#                                                2    source  1.000000  ...
#                                                     target  1.000000  ...
#                                                3    source  1.000000  ...
#                                                     target  1.000000  ...
#
#                                                                   10    2  \
# dataset         da_method domains              seed domain
# MINI_DOMAIN_NET HoMM      real_src-clipart_tgt 1    source  0.977597  NaN
#                                                     target  0.631148  NaN
#                                                2    source  0.957230  NaN
#                                                     target  0.590164  NaN
#                                                3    source  0.926680  NaN
# ...                                                              ...  ...
# MOONS           DSAN      0_src-1_tgt          1    target  0.977143  1.0
#                                                2    source  0.994286  1.0
#                                                     target  1.000000  1.0
#                                                3    source  1.000000  1.0
#                                                     target  0.942857  1.0
#
#                                                                    5  \
# dataset         da_method domains              seed domain
# MINI_DOMAIN_NET HoMM      real_src-clipart_tgt 1    source  0.965377
#                                                     target  0.540984
#                                                2    source  0.928717
#                                                     target  0.581967
#                                                3    source  0.959267
# ...                                                              ...
# MOONS           DSAN      0_src-1_tgt          1    target  1.000000
#                                                2    source  1.000000
#                                                     target  1.000000
#                                                3    source  1.000000
#                                                     target  1.000000
#
#                                                                  agg  \
# dataset         da_method domains              seed domain
# MINI_DOMAIN_NET HoMM      real_src-clipart_tgt 1    source  0.967413
#                                                     target  0.606557
#                                                2    source  0.965377
#                                                     target  0.590164
#                                                3    source  0.971487
# ...                                                              ...
# MOONS           DSAN      0_src-1_tgt          1    target  1.000000
#                                                2    source  1.000000
#                                                     target  1.000000
#                                                3    source  1.000000
#                                                     target  1.000000
#
#                                                                  dev  \
# dataset         da_method domains              seed domain
# MINI_DOMAIN_NET HoMM      real_src-clipart_tgt 1    source  0.965377
#                                                     target  0.540984
#                                                2    source  0.967413
#                                                     target  0.565574
#                                                3    source  0.973523
# ...                                                              ...
# MOONS           DSAN      0_src-1_tgt          1    target  1.000000
#                                                2    source  1.000000
#                                                     target  0.988571
#                                                3    source  1.000000
#                                                     target  0.982857
#
#                                                                  iwv  \
# dataset         da_method domains              seed domain
# MINI_DOMAIN_NET HoMM      real_src-clipart_tgt 1    source  0.965377
#                                                     target  0.540984
#                                                2    source  0.967413
#                                                     target  0.565574
#                                                3    source  0.963340
# ...                                                              ...
# MOONS           DSAN      0_src-1_tgt          1    target  1.000000
#                                                2    source  1.000000
#                                                     target  0.988571
#                                                3    source  1.000000
#                                                     target  0.982857
#
#                                                             source_reg  \
# dataset         da_method domains              seed domain
# MINI_DOMAIN_NET HoMM      real_src-clipart_tgt 1    source    0.981670
#                                                     target    0.549180
#                                                2    source    0.973523
#                                                     target    0.565574
#                                                3    source    0.973523
# ...                                                                ...
# MOONS           DSAN      0_src-1_tgt          1    target    1.000000
#                                                2    source    1.000000
#                                                     target    1.000000
#                                                3    source    1.000000
#                                                     target    1.000000
#
#                                                             target_confidence_reg  \
# dataset         da_method domains              seed domain
# MINI_DOMAIN_NET HoMM      real_src-clipart_tgt 1    source               0.969450
#                                                     target               0.581967
#                                                2    source               0.971487
#                                                     target               0.590164
#                                                3    source               0.965377
# ...                                                                           ...
# MOONS           DSAN      0_src-1_tgt          1    target               1.000000
#                                                2    source               1.000000
#                                                     target               1.000000
#                                                3    source               1.000000
#                                                     target               1.000000
#
#                                                             target_majority_reg  \
# dataset         da_method domains              seed domain
# MINI_DOMAIN_NET HoMM      real_src-clipart_tgt 1    source             0.963340
#                                                     target             0.573770
#                                                2    source             0.973523
#                                                     target             0.581967
#                                                3    source             0.965377
# ...                                                                         ...
# MOONS           DSAN      0_src-1_tgt          1    target             1.000000
#                                                2    source             1.000000
#                                                     target             1.000000
#                                                3    source             1.000000
#                                                     target             1.000000
#
#                                                             target_majority_vote
# dataset         da_method domains              seed domain
# MINI_DOMAIN_NET HoMM      real_src-clipart_tgt 1    source              0.959267
#                                                     target              0.598361
#                                                2    source              0.963340
#                                                     target              0.598361
#                                                3    source              0.965377
# ...                                                                          ...
# MOONS           DSAN      0_src-1_tgt          1    target              1.000000
#                                                2    source              1.000000
#                                                     target              1.000000
#                                                3    source              1.000000
#                                                     target              1.000000
#
# [2508 rows x 21 columns]

# %%
acc_df.dropna()
# Out:
#                                                     0    0.0001     0.001  \
# dataset da_method domains       seed domain
# WISDM   HoMM      18_src-23_tgt 1    source  1.000000  1.000000  1.000000
#                                      target  0.800000  0.766667  0.633333
#                                 2    source  1.000000  1.000000  1.000000
#                                      target  0.700000  0.800000  0.666667
#                                 3    source  1.000000  0.981132  1.000000
# ...                                               ...       ...       ...
# MOONS   DSAN      0_src-1_tgt   1    target  1.000000  1.000000  0.977143
#                                 2    source  1.000000  1.000000  1.000000
#                                      target  0.988571  1.000000  1.000000
#                                 3    source  1.000000  1.000000  1.000000
#                                      target  0.982857  0.994286  1.000000
#
#                                                  0.01      0.05       0.1  \
# dataset da_method domains       seed domain
# WISDM   HoMM      18_src-23_tgt 1    source  1.000000  1.000000  1.000000
#                                      target  0.700000  0.733333  0.733333
#                                 2    source  1.000000  1.000000  1.000000
#                                      target  0.766667  0.733333  0.666667
#                                 3    source  1.000000  1.000000  1.000000
# ...                                               ...       ...       ...
# MOONS   DSAN      0_src-1_tgt   1    target  0.994286  0.982857  1.000000
#                                 2    source  1.000000  1.000000  1.000000
#                                      target  1.000000  1.000000  1.000000
#                                 3    source  1.000000  1.000000  1.000000
#                                      target  0.994286  1.000000  1.000000
#
#                                                  0.25       0.5      0.75  \
# dataset da_method domains       seed domain
# WISDM   HoMM      18_src-23_tgt 1    source  1.000000  1.000000  1.000000
#                                      target  0.600000  0.666667  0.566667
#                                 2    source  1.000000  1.000000  1.000000
#                                      target  0.566667  0.566667  0.600000
#                                 3    source  1.000000  1.000000  1.000000
# ...                                               ...       ...       ...
# MOONS   DSAN      0_src-1_tgt   1    target  1.000000  1.000000  1.000000
#                                 2    source  1.000000  1.000000  1.000000
#                                      target  1.000000  1.000000  1.000000
#                                 3    source  1.000000  1.000000  1.000000
#                                      target  1.000000  1.000000  1.000000
#
#                                                     1  ...        10  \
# dataset da_method domains       seed domain            ...
# WISDM   HoMM      18_src-23_tgt 1    source  1.000000  ...  0.981132
#                                      target  0.666667  ...  0.666667
#                                 2    source  1.000000  ...  1.000000
#                                      target  0.600000  ...  0.633333
#                                 3    source  1.000000  ...  1.000000
# ...                                               ...  ...       ...
# MOONS   DSAN      0_src-1_tgt   1    target  1.000000  ...  0.977143
#                                 2    source  1.000000  ...  0.994286
#                                      target  1.000000  ...  1.000000
#                                 3    source  1.000000  ...  1.000000
#                                      target  1.000000  ...  0.942857
#
#                                                     2         5  agg  \
# dataset da_method domains       seed domain
# WISDM   HoMM      18_src-23_tgt 1    source  0.981132  0.981132  1.0
#                                      target  0.566667  0.566667  0.7
#                                 2    source  1.000000  1.000000  1.0
#                                      target  0.533333  0.633333  0.7
#                                 3    source  0.981132  0.981132  1.0
# ...                                               ...       ...  ...
# MOONS   DSAN      0_src-1_tgt   1    target  1.000000  1.000000  1.0
#                                 2    source  1.000000  1.000000  1.0
#                                      target  1.000000  1.000000  1.0
#                                 3    source  1.000000  1.000000  1.0
#                                      target  1.000000  1.000000  1.0
#
#                                                   dev       iwv  source_reg  \
# dataset da_method domains       seed domain
# WISDM   HoMM      18_src-23_tgt 1    source  1.000000  1.000000    1.000000
#                                      target  0.800000  0.800000    0.766667
#                                 2    source  1.000000  1.000000    1.000000
#                                      target  0.700000  0.700000    0.733333
#                                 3    source  1.000000  1.000000    1.000000
# ...                                               ...       ...         ...
# MOONS   DSAN      0_src-1_tgt   1    target  1.000000  1.000000    1.000000
#                                 2    source  1.000000  1.000000    1.000000
#                                      target  0.988571  0.988571    1.000000
#                                 3    source  1.000000  1.000000    1.000000
#                                      target  0.982857  0.982857    1.000000
#
#                                              target_confidence_reg  \
# dataset da_method domains       seed domain
# WISDM   HoMM      18_src-23_tgt 1    source               1.000000
#                                      target               0.800000
#                                 2    source               1.000000
#                                      target               0.766667
#                                 3    source               1.000000
# ...                                                            ...
# MOONS   DSAN      0_src-1_tgt   1    target               1.000000
#                                 2    source               1.000000
#                                      target               1.000000
#                                 3    source               1.000000
#                                      target               1.000000
#
#                                              target_majority_reg  \
# dataset da_method domains       seed domain
# WISDM   HoMM      18_src-23_tgt 1    source             1.000000
#                                      target             0.766667
#                                 2    source             1.000000
#                                      target             0.766667
#                                 3    source             1.000000
# ...                                                          ...
# MOONS   DSAN      0_src-1_tgt   1    target             1.000000
#                                 2    source             1.000000
#                                      target             1.000000
#                                 3    source             1.000000
#                                      target             1.000000
#
#                                              target_majority_vote
# dataset da_method domains       seed domain
# WISDM   HoMM      18_src-23_tgt 1    source                   1.0
#                                      target                   0.7
#                                 2    source                   1.0
#                                      target                   0.7
#                                 3    source                   1.0
# ...                                                           ...
# MOONS   DSAN      0_src-1_tgt   1    target                   1.0
#                                 2    source                   1.0
#                                      target                   1.0
#                                 3    source                   1.0
#                                      target                   1.0
#
# [2178 rows x 21 columns]

# %%
acc_df.columns, acc_df.index
# Out:
# (Index(['0', '0.0001', '0.001', '0.01', '0.05', '0.1', '0.25', '0.5', '0.75',
#         '1', '1.5', '10', '2', '5', 'agg', 'dev', 'iwv', 'source_reg',
#         'target_confidence_reg', 'target_majority_reg', 'target_majority_vote'],
#        dtype='object'),
#  MultiIndex([('MINI_DOMAIN_NET', 'HoMM',   'real_src-clipart_tgt', '1', ...),
#              ('MINI_DOMAIN_NET', 'HoMM',   'real_src-clipart_tgt', '1', ...),
#              ('MINI_DOMAIN_NET', 'HoMM',   'real_src-clipart_tgt', '2', ...),
#              ('MINI_DOMAIN_NET', 'HoMM',   'real_src-clipart_tgt', '2', ...),
#              ('MINI_DOMAIN_NET', 'HoMM',   'real_src-clipart_tgt', '3', ...),
#              ('MINI_DOMAIN_NET', 'HoMM',   'real_src-clipart_tgt', '3', ...),
#              ('MINI_DOMAIN_NET', 'HoMM', 'real_src-infograph_tgt', '1', ...),
#              ('MINI_DOMAIN_NET', 'HoMM', 'real_src-infograph_tgt', '1', ...),
#              ('MINI_DOMAIN_NET', 'HoMM', 'real_src-infograph_tgt', '2', ...),
#              ('MINI_DOMAIN_NET', 'HoMM', 'real_src-infograph_tgt', '2', ...),
#              ...
#              (          'MOONS', 'DANN',            '0_src-1_tgt', '2', ...),
#              (          'MOONS', 'DANN',            '0_src-1_tgt', '2', ...),
#              (          'MOONS', 'DANN',            '0_src-1_tgt', '3', ...),
#              (          'MOONS', 'DANN',            '0_src-1_tgt', '3', ...),
#              (          'MOONS', 'DSAN',            '0_src-1_tgt', '1', ...),
#              (          'MOONS', 'DSAN',            '0_src-1_tgt', '1', ...),
#              (          'MOONS', 'DSAN',            '0_src-1_tgt', '2', ...),
#              (          'MOONS', 'DSAN',            '0_src-1_tgt', '2', ...),
#              (          'MOONS', 'DSAN',            '0_src-1_tgt', '3', ...),
#              (          'MOONS', 'DSAN',            '0_src-1_tgt', '3', ...)],
#             names=['dataset', 'da_method', 'domains', 'seed', 'domain'], length=2508))

# %%
# acc_df.style

# %% [markdown]
# ### Count number of bad models
# **Criteria**: A model is bad if it reaches less than X percent of source performance on target
#
# **Procedure**:
# For counting the bad models, we must iterate over every experiment (2 rows at once, as each experiment yields a source and a target accuracy row).
# 1. Iterate over experiments (grouped by seed)
# 2. Take all individual model results (skip NaN values)
# 3. Apply bad model criterion, column-wise (pass all rows). Assign 1 if model is bad, 0 otherwise.
# 4. Keep target accuracy of baselines as columnss

# %%
# parameters
individual_models = ['0', '0.0001', '0.001', '0.01', '0.05', '0.1', '0.25', '0.5', '0.75', '1', '1.5', '10', '2', '5']
aggregation_methods = [
    'agg', 'dev', 'iwv', 'source_reg', 'target_confidence_reg', 'target_majority_reg', 'target_majority_vote'
]
model_counts = ['n_bad_models', 'n_models', 'frac_bad_models']

aggregation_specifier = {
    'n_bad_models': 'sum',
    'n_models': 'sum',
    'frac_bad_models': 'mean',
    'agg': 'mean',
    'dev': 'mean',
    'iwv': 'mean',
    'source_reg': 'mean',
    'target_confidence_reg': 'mean',
    'target_majority_reg': 'mean',
    'target_majority_vote': 'mean'
}

# %%
def count_models_based_on_treshold_criterion(
    acc_df: pd.DataFrame,
    frac_threshold: float,
    individual_models: List[str] = [
        '0', '0.0001', '0.001', '0.01', '0.05', '0.1', '0.25', '0.5', '0.75', '1', '1.5', '10', '2', '5'
    ],
    aggregation_methods: List[str] = [
        'agg', 'dev', 'iwv', 'source_reg', 'target_confidence_reg', 'target_majority_reg', 'target_majority_vote'
    ]
) -> pd.DataFrame:
    from functools import partial

    def bad_model_filter(source_target_acc: pd.Series,
                         source_only_target_accuracy: float,
                         performance_percentage_threshold: float = 0.95) -> float:
        """Returns 1 if model is bad, 0 otherwise.

        Args:
            source_target_acc (pd.Series): source and target performance.
            source_only_target_accuracy (float): source only accuracy
            performance_percentage_threshold (float, optional): Threshold to determine when model is bad: target < `performance_percentage_threshold`*source. Defaults to 0.8.

        Returns:
            float: 1. if model is bad, 0 otherwise
        """
        assert len(source_target_acc) == 2
        if source_target_acc.isna().any():
            return float('NaN')
        return float(source_target_acc[1] < performance_percentage_threshold * source_only_target_accuracy)

    index_tuples = []
    data_rows = []
    for index, df in acc_df.groupby(level=['dataset', 'da_method', 'domains', 'seed']):
        source_only_target_accuracy = df.xs(key='target', level='domain')['0'].item()
        criterion = partial(bad_model_filter, performance_percentage_threshold=frac_threshold, source_only_target_accuracy=source_only_target_accuracy)
        # find bad models
        bad_models = df[individual_models].apply(criterion, axis=0)
        # count bad models
        n_bad_models = bad_models.sum()
        # count total models (num non NaN)
        n_models = bad_models.notna().sum()
        counts = pd.Series({
            'n_bad_models': n_bad_models,
            'n_models': n_models,
            'frac_bad_models': float(n_bad_models) / n_models
        })
        # select target accuracy of aggregation methods
        target_acc_agg = df[aggregation_methods].xs(key='target', level='domain').iloc[0]  # select only acc

        dr = pd.concat([bad_models, counts, target_acc_agg])
        index_tuples.append(index)
        data_rows.append(dr)

    index = pd.MultiIndex.from_tuples(index_tuples, names=['dataset', 'da_method', 'domains', 'seed'])
    df = pd.DataFrame(data=data_rows, index=index)
    return df

# %%
res_df = count_models_based_on_treshold_criterion(acc_df, frac_threshold=0.6)

# %%
res_df = count_models_based_on_treshold_criterion(acc_df, frac_threshold=0.6)
display(res_df.groupby(level=['dataset']).agg(aggregation_specifier).style)
res_df.agg(aggregation_specifier)
# Out:
# <style type="text/css">
# </style>
# <table id="T_4c51c">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_4c51c_level0_col0" class="col_heading level0 col0" >n_bad_models</th>
#       <th id="T_4c51c_level0_col1" class="col_heading level0 col1" >n_models</th>
#       <th id="T_4c51c_level0_col2" class="col_heading level0 col2" >frac_bad_models</th>
#       <th id="T_4c51c_level0_col3" class="col_heading level0 col3" >agg</th>
#       <th id="T_4c51c_level0_col4" class="col_heading level0 col4" >dev</th>
#       <th id="T_4c51c_level0_col5" class="col_heading level0 col5" >iwv</th>
#       <th id="T_4c51c_level0_col6" class="col_heading level0 col6" >source_reg</th>
#       <th id="T_4c51c_level0_col7" class="col_heading level0 col7" >target_confidence_reg</th>
#       <th id="T_4c51c_level0_col8" class="col_heading level0 col8" >target_majority_reg</th>
#       <th id="T_4c51c_level0_col9" class="col_heading level0 col9" >target_majority_vote</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >dataset</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#       <th class="blank col9" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_4c51c_level0_row0" class="row_heading level0 row0" >AMAZON_REVIEWS</th>
#       <td id="T_4c51c_row0_col0" class="data row0 col0" >0.000000</td>
#       <td id="T_4c51c_row0_col1" class="data row0 col1" >5544.000000</td>
#       <td id="T_4c51c_row0_col2" class="data row0 col2" >0.000000</td>
#       <td id="T_4c51c_row0_col3" class="data row0 col3" >0.787881</td>
#       <td id="T_4c51c_row0_col4" class="data row0 col4" >0.764435</td>
#       <td id="T_4c51c_row0_col5" class="data row0 col5" >0.772056</td>
#       <td id="T_4c51c_row0_col6" class="data row0 col6" >0.789340</td>
#       <td id="T_4c51c_row0_col7" class="data row0 col7" >0.785694</td>
#       <td id="T_4c51c_row0_col8" class="data row0 col8" >0.786152</td>
#       <td id="T_4c51c_row0_col9" class="data row0 col9" >0.787037</td>
#     </tr>
#     <tr>
#       <th id="T_4c51c_level0_row1" class="row_heading level0 row1" >EEG</th>
#       <td id="T_4c51c_row1_col0" class="data row1 col0" >42.000000</td>
#       <td id="T_4c51c_row1_col1" class="data row1 col1" >2310.000000</td>
#       <td id="T_4c51c_row1_col2" class="data row1 col2" >0.018182</td>
#       <td id="T_4c51c_row1_col3" class="data row1 col3" >0.736567</td>
#       <td id="T_4c51c_row1_col4" class="data row1 col4" >0.660194</td>
#       <td id="T_4c51c_row1_col5" class="data row1 col5" >0.700137</td>
#       <td id="T_4c51c_row1_col6" class="data row1 col6" >0.717225</td>
#       <td id="T_4c51c_row1_col7" class="data row1 col7" >0.725043</td>
#       <td id="T_4c51c_row1_col8" class="data row1 col8" >0.728996</td>
#       <td id="T_4c51c_row1_col9" class="data row1 col9" >0.729223</td>
#     </tr>
#     <tr>
#       <th id="T_4c51c_level0_row2" class="row_heading level0 row2" >HAR</th>
#       <td id="T_4c51c_row2_col0" class="data row2 col0" >74.000000</td>
#       <td id="T_4c51c_row2_col1" class="data row2 col1" >2310.000000</td>
#       <td id="T_4c51c_row2_col2" class="data row2 col2" >0.032035</td>
#       <td id="T_4c51c_row2_col3" class="data row2 col3" >0.835101</td>
#       <td id="T_4c51c_row2_col4" class="data row2 col4" >0.764646</td>
#       <td id="T_4c51c_row2_col5" class="data row2 col5" >0.773801</td>
#       <td id="T_4c51c_row2_col6" class="data row2 col6" >0.769129</td>
#       <td id="T_4c51c_row2_col7" class="data row2 col7" >0.832449</td>
#       <td id="T_4c51c_row2_col8" class="data row2 col8" >0.833333</td>
#       <td id="T_4c51c_row2_col9" class="data row2 col9" >0.840341</td>
#     </tr>
#     <tr>
#       <th id="T_4c51c_level0_
#       <td id="T_4c51c_row6_col7" class="data row6 col7" >0.764640</td>
#       <td id="T_4c51c_row6_col8" class="data row6 col8" >0.767785</td>
#       <td id="T_4c51c_row6_col9" class="data row6 col9" >0.768284</td>
#     </tr>
#   </tbody>
# </table>
# n_bad_models               297.000000
# n_models                 16566.000000
# frac_bad_models              0.017473
# agg                          0.755707
# dev                          0.712857
# iwv                          0.726249
# source_reg                   0.730947
# target_confidence_reg        0.750579
# target_majority_reg          0.750873
# target_majority_vote         0.752597
# dtype: float64

# %%
res_df = count_models_based_on_treshold_criterion(acc_df, frac_threshold=0.7)
display(res_df.groupby(level=['dataset']).agg(aggregation_specifier).style)
res_df.agg(aggregation_specifier)
# Out:
# <style type="text/css">
# </style>
# <table id="T_b9214">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b9214_level0_col0" class="col_heading level0 col0" >n_bad_models</th>
#       <th id="T_b9214_level0_col1" class="col_heading level0 col1" >n_models</th>
#       <th id="T_b9214_level0_col2" class="col_heading level0 col2" >frac_bad_models</th>
#       <th id="T_b9214_level0_col3" class="col_heading level0 col3" >agg</th>
#       <th id="T_b9214_level0_col4" class="col_heading level0 col4" >dev</th>
#       <th id="T_b9214_level0_col5" class="col_heading level0 col5" >iwv</th>
#       <th id="T_b9214_level0_col6" class="col_heading level0 col6" >source_reg</th>
#       <th id="T_b9214_level0_col7" class="col_heading level0 col7" >target_confidence_reg</th>
#       <th id="T_b9214_level0_col8" class="col_heading level0 col8" >target_majority_reg</th>
#       <th id="T_b9214_level0_col9" class="col_heading level0 col9" >target_majority_vote</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >dataset</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#       <th class="blank col9" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b9214_level0_row0" class="row_heading level0 row0" >AMAZON_REVIEWS</th>
#       <td id="T_b9214_row0_col0" class="data row0 col0" >14.000000</td>
#       <td id="T_b9214_row0_col1" class="data row0 col1" >5544.000000</td>
#       <td id="T_b9214_row0_col2" class="data row0 col2" >0.002525</td>
#       <td id="T_b9214_row0_col3" class="data row0 col3" >0.787881</td>
#       <td id="T_b9214_row0_col4" class="data row0 col4" >0.764435</td>
#       <td id="T_b9214_row0_col5" class="data row0 col5" >0.772056</td>
#       <td id="T_b9214_row0_col6" class="data row0 col6" >0.789340</td>
#       <td id="T_b9214_row0_col7" class="data row0 col7" >0.785694</td>
#       <td id="T_b9214_row0_col8" class="data row0 col8" >0.786152</td>
#       <td id="T_b9214_row0_col9" class="data row0 col9" >0.787037</td>
#     </tr>
#     <tr>
#       <th id="T_b9214_level0_row1" class="row_heading level0 row1" >EEG</th>
#       <td id="T_b9214_row1_col0" class="data row1 col0" >106.000000</td>
#       <td id="T_b9214_row1_col1" class="data row1 col1" >2310.000000</td>
#       <td id="T_b9214_row1_col2" class="data row1 col2" >0.045887</td>
#       <td id="T_b9214_row1_col3" class="data row1 col3" >0.736567</td>
#       <td id="T_b9214_row1_col4" class="data row1 col4" >0.660194</td>
#       <td id="T_b9214_row1_col5" class="data row1 col5" >0.700137</td>
#       <td id="T_b9214_row1_col6" class="data row1 col6" >0.717225</td>
#       <td id="T_b9214_row1_col7" class="data row1 col7" >0.725043</td>
#       <td id="T_b9214_row1_col8" class="data row1 col8" >0.728996</td>
#       <td id="T_b9214_row1_col9" class="data row1 col9" >0.729223</td>
#     </tr>
#     <tr>
#       <th id="T_b9214_level0_
#       <td id="T_b9214_row6_col0" class="data row6 col0" >179.000000</td>
#       <td id="T_b9214_row6_col1" class="data row6 col1" >2310.000000</td>
#       <td id="T_b9214_row6_col2" class="data row6 col2" >0.077489</td>
#       <td id="T_b9214_row6_col3" class="data row6 col3" >0.763716</td>
#       <td id="T_b9214_row6_col4" class="data row6 col4" >0.725823</td>
#       <td id="T_b9214_row6_col5" class="data row6 col5" >0.735742</td>
#       <td id="T_b9214_row6_col6" class="data row6 col6" >0.737171</td>
#       <td id="T_b9214_row6_col7" class="data row6 col7" >0.764640</td>
#       <td id="T_b9214_row6_col8" class="data row6 col8" >0.767785</td>
#       <td id="T_b9214_row6_col9" class="data row6 col9" >0.768284</td>
#     </tr>
#   </tbody>
# </table>
# n_bad_models               551.000000
# n_models                 16566.000000
# frac_bad_models              0.032411
# agg                          0.755707
# dev                          0.712857
# iwv                          0.726249
# source_reg                   0.730947
# target_confidence_reg        0.750579
# target_majority_reg          0.750873
# target_majority_vote         0.752597
# dtype: float64

# %%
frac_threshold=0.8
res_df = count_models_based_on_treshold_criterion(acc_df, frac_threshold=frac_threshold)
print(f'Frac threshold:{}')
display(res_df.groupby(level=['dataset']).agg(aggregation_specifier).style)
res_df.agg(aggregation_specifier)
# Out:
# <style type="text/css">
# </style>
# <table id="T_5fdda">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_5fdda_level0_col0" class="col_heading level0 col0" >n_bad_models</th>
#       <th id="T_5fdda_level0_col1" class="col_heading level0 col1" >n_models</th>
#       <th id="T_5fdda_level0_col2" class="col_heading level0 col2" >frac_bad_models</th>
#       <th id="T_5fdda_level0_col3" class="col_heading level0 col3" >agg</th>
#       <th id="T_5fdda_level0_col4" class="col_heading level0 col4" >dev</th>
#       <th id="T_5fdda_level0_col5" class="col_heading level0 col5" >iwv</th>
#       <th id="T_5fdda_level0_col6" class="col_heading level0 col6" >source_reg</th>
#       <th id="T_5fdda_level0_col7" class="col_heading level0 col7" >target_confidence_reg</th>
#       <th id="T_5fdda_level0_col8" class="col_heading level0 col8" >target_majority_reg</th>
#       <th id="T_5fdda_level0_col9" class="col_heading level0 col9" >target_majority_vote</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >dataset</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#       <th class="blank col9" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_5fdda_level0_row0" class="row_heading level0 row0" >AMAZON_REVIEWS</th>
#       <td id="T_5fdda_row0_col0" class="data row0 col0" >81.000000</td>
#       <td id="T_5fdda_row0_col1" class="data row0 col1" >5544.000000</td>
#       <td id="T_5fdda_row0_col2" class="data row0 col2" >0.014610</td>
#       <td id="T_5fdda_row0_col3" class="data row0 col3" >0.787881</td>
#       <td id="T_5fdda_row0_col4" class="data row0 col4" >0.764435</td>
#       <td id="T_5fdda_row0_col5" class="data row0 col5" >0.772056</td>
#       <td id="T_5fdda_row0_col6" class="data row0 col6" >0.789340</td>
#       <td id="T_5fdda_row0_col7" class="data row0 col7" >0.785694</td>
#       <td id="T_5fdda_row0_col8" class="data row0 col8" >0.786152</td>
#       <td id="T_5fdda_row0_col9" class="data row0 col9" >0.787037</td>
#     </tr>
#     <tr>
#       <th id="T_5fdda_level0_
td>
#     </tr>
#     <tr>
#       <th id="T_5fdda_level0_row5" class="row_heading level0 row5" >MOONS</th>
#       <td id="T_5fdda_row5_col0" class="data row5 col0" >23.000000</td>
#       <td id="T_5fdda_row5_col1" class="data row5 col1" >462.000000</td>
#       <td id="T_5fdda_row5_col2" class="data row5 col2" >0.049784</td>
#       <td id="T_5fdda_row5_col3" class="data row5 col3" >0.997229</td>
#       <td id="T_5fdda_row5_col4" class="data row5 col4" >0.980606</td>
#       <td id="T_5fdda_row5_col5" class="data row5 col5" >0.989264</td>
#       <td id="T_5fdda_row5_col6" class="data row5 col6" >0.988918</td>
#       <td id="T_5fdda_row5_col7" class="data row5 col7" >0.997403</td>
#       <td id="T_5fdda_row5_col8" class="data row5 col8" >0.980779</td>
#       <td id="T_5fdda_row5_col9" class="data row5 col9" >0.979567</td>
#     </tr>
#     <tr>
#       <th id="T_5fdda_level0_row6" class="row_heading level0 row6" >WISDM</th>
#       <td id="T_5fdda_row6_col0" class="data row6 col0" >317.000000</td>
#       <td id="T_5fdda_row6_col1" class="data row6 col1" >2310.000000</td>
#       <td id="T_5fdda_row6_col2" class="data row6 col2" >0.137229</td>
#       <td id="T_5fdda_row6_col3" class="data row6 col3" >0.763716</td>
#       <td id="T_5fdda_row6_col4" class="data row6 col4" >0.725823</td>
#       <td id="T_5fdda_row6_col5" class="data row6 col5" >0.735742</td>
#       <td id="T_5fdda_row6_col6" class="data row6 col6" >0.737171</td>
#       <td id="T_5fdda_row6_col7" class="data row6 col7" >0.764640</td>
#       <td id="T_5fdda_row6_col8" class="data row6 col8" >0.767785</td>
#       <td id="T_5fdda_row6_col9" class="data row6 col9" >0.768284</td>
#     </tr>
#   </tbody>
# </table>
# n_bad_models              1038.000000
# n_models                 16566.000000
# frac_bad_models              0.061133
# agg                          0.755707
# dev                          0.712857
# iwv                          0.726249
# source_reg                   0.730947
# target_confidence_reg        0.750579
# target_majority_reg          0.750873
# target_majority_vote         0.752597
# dtype: float64

# %%
res_df = count_models_based_on_treshold_criterion(acc_df, frac_threshold=0.85)
display(res_df.groupby(level=['dataset']).agg(aggregation_specifier).style)
res_df.agg(aggregation_specifier)
# Out:
# <style type="text/css">
# </style>
# <table id="T_40310">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_40310_level0_col0" class="col_heading level0 col0" >n_bad_models</th>
#       <th id="T_40310_level0_col1" class="col_heading level0 col1" >n_models</th>
#       <th id="T_40310_level0_col2" class="col_heading level0 col2" >frac_bad_models</th>
#       <th id="T_40310_level0_col3" class="col_heading level0 col3" >agg</th>
#       <th id="T_40310_level0_col4" class="col_heading level0 col4" >dev</th>
#       <th id="T_40310_level0_col5" class="col_heading level0 col5" >iwv</th>
#       <th id="T_40310_level0_col6" class="col_heading level0 col6" >source_reg</th>
#       <th id="T_40310_level0_col7" class="col_heading level0 col7" >target_confidence_reg</th>
#       <th id="T_40310_level0_col8" class="col_heading level0 col8" >target_majority_reg</th>
#       <th id="T_40310_level0_col9" class="col_heading level0 col9" >target_majority_vote</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >dataset</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#       <th class="blank col9" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_40310_level0_row0" class="row_heading level0 row0" >AMAZON_REVIEWS</th>
#       <td id="T_40310_row0_col0" class="data row0 col0" >123.000000</td>
#       <td id="T_40310_row0_col1" class="data row0 col1" >5544.000000</td>
#       <td id="T_40310_row0_col2" class="data row0 col2" >0.022186</td>
#       <td id="T_40310_row0_col3" class="data row0 col3" >0.787881</td>
td>
#     </tr>
#     <tr>
#       <th id="T_40310_level0_row5" class="row_heading level0 row5" >MOONS</th>
#       <td id="T_40310_row5_col0" class="data row5 col0" >30.000000</td>
#       <td id="T_40310_row5_col1" class="data row5 col1" >462.000000</td>
#       <td id="T_40310_row5_col2" class="data row5 col2" >0.064935</td>
#       <td id="T_40310_row5_col3" class="data row5 col3" >0.997229</td>
#       <td id="T_40310_row5_col4" class="data row5 col4" >0.980606</td>
#       <td id="T_40310_row5_col5" class="data row5 col5" >0.989264</td>
#       <td id="T_40310_row5_col6" class="data row5 col6" >0.988918</td>
#       <td id="T_40310_row5_col7" class="data row5 col7" >0.997403</td>
#       <td id="T_40310_row5_col8" class="data row5 col8" >0.980779</td>
#       <td id="T_40310_row5_col9" class="data row5 col9" >0.979567</td>
#     </tr>
#     <tr>
#       <th id="T_40310_level0_row6" class="row_heading level0 row6" >WISDM</th>
#       <td id="T_40310_row6_col0" class="data row6 col0" >422.000000</td>
#       <td id="T_40310_row6_col1" class="data row6 col1" >2310.000000</td>
#       <td id="T_40310_row6_col2" class="data row6 col2" >0.182684</td>
#       <td id="T_40310_row6_col3" class="data row6 col3" >0.763716</td>
#       <td id="T_40310_row6_col4" class="data row6 col4" >0.725823</td>
#       <td id="T_40310_row6_col5" class="data row6 col5" >0.735742</td>
#       <td id="T_40310_row6_col6" class="data row6 col6" >0.737171</td>
#       <td id="T_40310_row6_col7" class="data row6 col7" >0.764640</td>
#       <td id="T_40310_row6_col8" class="data row6 col8" >0.767785</td>
#       <td id="T_40310_row6_col9" class="data row6 col9" >0.768284</td>
#     </tr>
#   </tbody>
# </table>
# n_bad_models              1437.000000
# n_models                 16566.000000
# frac_bad_models              0.084800
# agg                          0.755707
# dev                          0.712857
# iwv                          0.726249
# source_reg                   0.730947
# target_confidence_reg        0.750579
# target_majority_reg          0.750873
# target_majority_vote         0.752597
# dtype: float64

# %%
res_df = count_models_based_on_treshold_criterion(acc_df, frac_threshold=0.9)
display(res_df.groupby(level=['dataset']).agg(aggregation_specifier).style)
res_df.agg(aggregation_specifier)
# Out:
# <style type="text/css">
# </style>
# <table id="T_1fe98">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_1fe98_level0_col0" class="col_heading level0 col0" >n_bad_models</th>
#       <th id="T_1fe98_level0_col1" class="col_heading level0 col1" >n_models</th>
#       <th id="T_1fe98_level0_col2" class="col_heading level0 col2" >frac_bad_models</th>
#       <th id="T_1fe98_level0_col3" class="col_heading level0 col3" >agg</th>
#       <th id="T_1fe98_level0_col4" class="col_heading level0 col4" >dev</th>
#       <th id="T_1fe98_level0_col5" class="col_heading level0 col5" >iwv</th>
#       <th id="T_1fe98_level0_col6" class="col_heading level0 col6" >source_reg</th>
#       <th id="T_1fe98_level0_col7" class="col_heading level0 col7" >target_confidence_reg</th>
#       <th id="T_1fe98_level0_col8" class="col_heading level0 col8" >target_majority_reg</th>
#       <th id="T_1fe98_level0_col9" class="col_heading level0 col9" >target_majority_vote</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >dataset</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#       <th class="blank col9" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_1fe98_level0_row0" class="row_heading level0 row0" >AMAZON_REVIEWS</th>
#       <td id="T_1fe98_row0_col0" class="data row0 col0" >185.000000</td>
#       <td id="T_1fe98_row0_col1" class="data row0 col1" >5544.000000</td>
#       <td id="T_1fe98_row0_col2" class="data row0 col2" >0.033369</td>
#       <td id="T_1fe98_row0_col3" class="data row0 col3" >0.787881</td>
#       <td id="T_1fe98_row0_col4" class="data row0 col4" >0.764435</td>
#       <td id="T_1fe98_row0_col5" class="data row0 col5" >0.772056</td>
#       <td id="T_1fe98_row0_col6" class="data row0 col6" >0.789340</td>
#       <td id="T_1fe98_row0_col7" class="data row0 col7" >0.785694</td>
#       <td id="T_1fe98_row0_col8" class="data row0 col8" >0.786152</td>
#       <td id="T_1fe98_row0_col9" class="data row0 col9" >0.787037</td>
#     </tr>
#     <tr>
#       <th id="T_1fe98_level0_row1" class="row_heading level0 row1" >EEG</th>
#       <td id="T_1fe98_row1_col0" class="data row1 col0" >387.000000</td>
#       <td id="T_1fe98_row1_col1" class="data row1 col1" >2310.000000</td>
#       <td id="T_1fe98_row1_col2" class="data row1 col2" >0.167532</td>
#       <td id="T_1fe98_row1_col3" class="data row1 col3" >0.736567</td>
#       <td id="T_1fe98_row1_col4" class="data row1 col4" >0.660194</td>
#       <td id="T_1fe98_row1_col5" class="data row1 col5" >0.700137</td>
#       <td id="T_1fe98_row1_col6" class="data row1 col6" >0.717225</td>
#       <td id="T_1fe98_row1_col7" class="data row1 col7" >0.725043</td>
#       <td id="T_1fe98_row1_col8" class="data row1 col8" >0.728996</td>
#       <td id="T_1fe98_row1_col9" class="data row1 col9" >0.729223</td>
#     </tr>
#     <tr>
#       <th id="T_1fe98_level0_row2" class="row_heading level0 row2" >HAR</th>
#       <td id="T_1fe98_row2_col0" class="data row2 col0" >281.000000</td>
#       <td id="T_1fe98_row2_col1" class="data row2 col1" >2310.000000</td>
#       <td id="T_1fe98_row2_col2" class="data row2 col2" >0.121645</td>
#       <td id="T_1fe98_row2_col3" class="data row2 col3" >0.835101</td>
#       <td id="T_1fe98_row2_col4" class="data row2 col4" >0.764646</td>
#       <td id="T_1fe98_row2_col5" class="data row2 col5" >0.773801</td>
#       <td id="T_1fe98_row2_col6" class="data row2 col6" >0.769129</td>
#       <td id="T_1fe98_row2_col7" class="data row2 col7" >0.832449</td>
#       <td id="T_1fe98_row2_col8" class="data row2 col8" >0.833333</td>
#       <td id="T_1fe98_row2_col9" class="data row2 col9" >0.840341</td>
#     </tr>
#     <tr>
#       <th id="T_1fe98_level0_row3" class="row_heading level0 row3" >HHAR_SA</th>
#       <td id="T_1fe98_row3_col0" class="data row3 col0" >415.000000</td>
#       <td id="T_1fe98_row3_col1" class="data row3 col1" >2310.000000</td>
#       <td id="T_1fe98_row3_col2" class="data row3 col2" >0.179654</td>
#       <td id="T_1fe98_row3_col3" class="data row3 col3" >0.786932</td>
#       <td id="T_1fe98_row3_col4" class="data row3 col4" >0.721751</td>
#       <td id="T_1fe98_row3_col5" class="data row3 col5" >0.745790</td>
#       <td id="T_1fe98_row3_col6" class="data row3 col6" >0.721612</td>
#       <td id="T_1fe98_row3_col7" class="data row3 col7" >0.771226</td>
#       <td id="T_1fe98_row3_col8" class="data row3 col8" >0.768314</td>
#       <td id="T_1fe98_row3_col9" class="data row3 col9" >0.770606</td>
#     </tr>
#     <tr>
#       <th id="T_1fe98_level0_row4" class="row_heading level0 row4" >MINI_DOMAIN_NET</th>
#       <td id="T_1fe98_row4_col0" class="data row4 col0" >106.000000</td>
#       <td id="T_1fe98_row4_col1" class="data row4 col1" >1320.000000</td>
#       <td id="T_1fe98_row4_col2" class="data row4 col2" >0.080303</td>
#       <td id="T_1fe98_row4_col3" class="data row4 col3" >0.530699</td>
#       <td id="T_1fe98_row4_col4" class="data row4 col4" >0.514537</td>
#       <td id="T_1fe98_row4_col5" class="data row4 col5" >0.513236</td>
#       <td id="T_1fe98_row4_col6" class="data row4 col6" >0.517864</td>
#       <td id="T_1fe98_row4_col7" class="data row4 col7" >0.525897</td>
#       <td id="T_1fe98_row4_col8" class="data row4 col8" >0.525289</td>
#       <td id="T_1fe98_row4_col9" class="data row4 col9" >0.526479</td>
#     </tr>
#     <tr>
#       <th id="T_1fe98_level0_row5" class="row_heading level0 row5" >MOONS</th>
#       <td id="T_1fe98_row5_col0" class="data row5 col0" >40.000000</td>
#       <td id="T_1fe98_row5_col1" class="data row5 col1" >462.000000</td>
#       <td id="T_1fe98_row5_col2" class="data row5 col2" >0.086580</td>
#       <td id="T_1fe98_row5_col3" class="data row5 col3" >0.997229</td>
#       <td id="T_1fe98_row5_col4" class="data row5 col4" >0.980606</td>
#       <td id="T_1fe98_row5_col5" class="data row5 col5" >0.989264</td>
#       <td id="T_1fe98_row5_col6" class="data row5 col6" >0.988918</td>
#       <td id="T_1fe98_row5_col7" class="data row5 col7" >0.997403</td>
#       <td id="T_1fe98_row5_col8" class="data row5 col8" >0.980779</td>
#       <td id="T_1fe98_row5_col9" class="data row5 col9" >0.979567</td>
#     </tr>
#     <tr>
#       <th id="T_1fe98_level0_row6" class="row_heading level0 row6" >WISDM</th>
#       <td id="T_1fe98_row6_col0" class="data row6 col0" >613.000000</td>
#       <td id="T_1fe98_row6_col1" class="data row6 col1" >2310.000000</td>
#       <td id="T_1fe98_row6_col2" class="data row6 col2" >0.265368</td>
#       <td id="T_1fe98_row6_col3" class="data row6 col3" >0.763716</td>
#       <td id="T_1fe98_row6_col4" class="data row6 col4" >0.725823</td>
#       <td id="T_1fe98_row6_col5" class="data row6 col5" >0.735742</td>
#       <td id="T_1fe98_row6_col6" class="data row6 col6" >0.737171</td>
#       <td id="T_1fe98_row6_col7" class="data row6 col7" >0.764640</td>
#       <td id="T_1fe98_row6_col8" class="data row6 col8" >0.767785</td>
#       <td id="T_1fe98_row6_col9" class="data row6 col9" >0.768284</td>
#     </tr>
#   </tbody>
# </table>
# n_bad_models              2027.000000
# n_models                 16566.000000
# frac_bad_models              0.119987
# agg                          0.755707
# dev                          0.712857
# iwv                          0.726249
# source_reg                   0.730947
# target_confidence_reg        0.750579
# target_majority_reg          0.750873
# target_majority_vote         0.752597
# dtype: float64

# %%
# save table
# import dataframe_image as dfi
# dfi.export(mean_corr_per_dataset_dam, 'mean_corr_per_dataset_dam.png', dpi=300)
